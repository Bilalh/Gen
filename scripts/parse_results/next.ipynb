# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

from analyse import *
from IPython.display import HTML
from IPython.display import display

df = load_data_frame()
param_eprime_info = load_data_frame_param_eprime_info()
pd.options.display.line_width = 110
pd.options.display.max_columns = 250
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
display(df)
# display(param_eprime_info)
# display(df.essence.unique())
df['method_count'] = df['method']
df.method_count=df.method_count.apply(func=lambda x:len( df[df.method ==x]) )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 0 to 759
# Data columns (total 20 columns):
# chain_length               87  non-null values
# discriminating             760  non-null values
# essence                    760  non-null values
# index                      760  non-null values
# influence_radius           612  non-null values
# method                     760  non-null values
# models_timeout             760  non-null values
# num_models                 760  non-null values
# num_points                 393  non-null values
# output_dir                 760  non-null values
# point_selector             393  non-null values
# quality                    290  non-null values
# races                      760  non-null values
# radius_as_percentage       612  non-null values
# run_no                     760  non-null values
# total_timeout              760  non-null values
# resulting_models           290  non-null values
# resulting_models_filled    760  non-null values
# total_timeout_h            760  non-null values
# group_num                  760  non-null values
# dtypes: float64(8), int64(8), object(4)

# %%
def plot_grid(*, our, cols_names, use_discriminating=False, legend=True ):
    
    if use_discriminating:
        values='discriminating'
        x_axis_name='number of distinguishing params'
        pass
    else:
        values='resulting_models_filled'
        x_axis_name='models left'
    
    pt=our.pivot_table(rows=['total_timeout_h'],
                       cols=cols_names,
                       values=values)
    
    rows = our[cols_names[0]].unique()
    cols = our[cols_names[1]].unique()
    print("rows:", rows, "cols:", cols)
    
    r_limits =( our['total_timeout_h'].dropna().min(),  our['total_timeout_h'].dropna().max())
    
    lens = ( (i,j, pt[r][c].columns ) for i, r in  enumerate(rows)  for j, c in enumerate(cols) )
    max_val = max(lens,key=lambda v: len(v[2]))
    *max_val, _ = max_val
    
    legend_names=our[cols_names[2]].unique()
    styles = ['#0000FF', '#FF00FF', '#008080', '#008000', '#FFFF00', '#00FF00', '#800080', '#00FFFF', '#C0C0C0', '#000080', 
              '#FF0000', '#808000', '#000000', '#FFA500', '#808080', '#800000']
    display(legend_names)
    styles_mapping = make_style_mapping(legend_names, styles)
#     display( [ ele for ele in sorted(styles_mapping.keys())
#               if set(['ksample_first-100.0-10.0', 'ksample_first-20.0-10.0', 'ksample_halving-100.0-10.0',
#                       'ksample_halving-20.0-10.0', 'uniform']) <= set(ele)
#               ])  
    
    fig, axes = plt.subplots(nrows=max(len(rows),2), ncols=max(len(cols),2), figsize=(20, 17), sharex=True, sharey='row')
    for i, v1 in enumerate( rows ):
        if not use_discriminating:
            col_vals= our[ (our[cols_names[0]] == v1) ]['num_models'].dropna()
            ylim = (0, col_vals.max())
        else:
            col_vals = our[ (our[cols_names[0]] == v1) ]['discriminating'].dropna().max()
            ylim = (0, max(3, col_vals.max()))
        
        for j, v2 in enumerate( cols ):
            if pt[v1][v2].empty: # not done yet
                continue
    
            colss = tuple(sorted(pt[v1][v2].columns))
#             display(list(styles_mapping[colss]))
            pt[v1][v2].dropna().plot(ax=axes[i][j],
                                     title="{}: {},   {}: {}".format(cols_names[1], v2, cols_names[0], v1), 
                                     color=list(styles_mapping[colss]), 
                                     marker='o',
                                     legend=legend,
                                     xlim=r_limits,
                                     ylim=ylim)
    
        axes[i][0].set_ylabel(x_axis_name)
        
    display(pt)
    
    fig.legend( axes[max_val[0]][max_val[1]].get_lines() ,
               legend_names, 
               loc = 'upper center', 
               ncol=5 )

# %%
df['method2'] = df['method']
# c = df[ df.essence == 'efpa' ] 
c = df[ df.total_timeout_h >= 3 ] 

ks= c[ c.method == 'ksample' ] 
ks['method2'] = ks.apply(lambda x:'{}_{}-{}-{}'.format
                         (x['method'], x['point_selector'], x['num_points'], x['influence_radius']),
                         axis=1)
# ks['method2'] = df.point_selector.map(str) + "-" + df.influence_radius.map(str)
c[ c.method == 'ksample' ] = ks


ns= c[ c.method == 'nsample' ] 
ns['method2'] = ns.apply(lambda x:'{}_{}'.format
                         (x['method'], x['influence_radius']),
                         axis=1)
c[ c.method == 'nsample' ] = ns


ms= c[ c.method == 'markov' ] 
ms['method2'] = ms.apply(lambda x:'{}_{}_{}'.format
                         (x['method'],x['chain_length'], x['influence_radius']),
                         axis=1)
c[ c.method == 'markov' ] = ms


c['method2_count'] = c['method2']
c.method2_count=c.method2_count.apply(func=lambda x:len( c[c.method2 ==x]) )

# %%
plot_grid(our = c,
          cols_names=['essence','races','method2'],
          use_discriminating=False,
          legend=False
         )

from matplotlib.backends.backend_pdf import PdfPages
with PdfPages('/Users/bilalh/Desktop/a.pdf') as pdf:
    pdf.savefig()
# Out:
# rows: ['prob028-Bibd' 'efpa' 'prob024-Langford' 'prob010-SCP'] cols: [ 5 50 25 10]
# array(['ksample_first-20.0-10.0', 'ksample_halving-20.0-10.0',
#        'ksample_first-100.0-10.0', 'ksample_halving-100.0-10.0',
#        'markov_10.0_4.0', 'markov_10.0_10.0', 'markov_1000.0_4.0',
#        'markov_1000.0_10.0', 'nsample_4.0', 'nsample_10.0', 'smac',
#        'uniform', 'ksample_first-1000.0-10.0',
#        'ksample_halving-1000.0-10.0'], dtype=object)
# essence                              efpa                                                       \
# races                                  5
# method2          ksample_first-100.0-10.0  ksample_first-20.0-10.0  ksample_halving-100.0-10.0
# total_timeout_h
# 3.00                                  NaN                      NaN                         NaN
# 5.25                                  NaN                      NaN                         NaN
# 6.00                                   45                     24.5                          45
# 12.00                                  45                     24.5                          45
# 21.00                                 NaN                      NaN                         NaN
# 24.00                                  45                     45.0                          45
#
# essence                                                                                            \
# races
# method2          ksample_halving-20.0-10.0  markov_10.0_10.0  markov_10.0_4.0  markov_1000.0_10.0
# total_timeout_h
# 3.00                                   NaN               NaN              NaN                 NaN
# 5.25                                   NaN               NaN              NaN                 NaN
# 6.00                                    45                45               45                  45
# 12.00                                   45                45               45                  45
# 21.00                                  NaN               NaN              NaN                 NaN
# 24.00                                   45                45               45                   8
#
# essence                                                                                                 \
# races                                                                                               10
# method2          markov_1000.0_4.0  nsample_10.0  nsample_4.0  smac  uniform  ksample_first-100.0-10.0
# total_timeout_h
# 3.00                           NaN           NaN          NaN   NaN      NaN                       NaN
# 5.25                           NaN           NaN          NaN   NaN      NaN                       NaN
# 6.00                            45            45           45    45       45                        23
# 12.00                           45            45           45    45       45                        45
# 21.00                          NaN           NaN          NaN   NaN      NaN                       NaN
# 24.00                            4            45           23    23       45                        45
#
# essence                                                                                          \
# races
# method2          ksample_first-20.0-10.0  ksample_halving-100.0-10.0  ksample_halving-20.0-10.0
# total_timeout_h
# 3.00                                 NaN                         NaN                        NaN
# 5.25                                 NaN                         NaN                        NaN
# 6.00                                45.0                          45                       45.0
# 12.00                                4.5                          45                       45.0
# 21.00                                NaN                         NaN                        NaN
# 24.00                               45.0                          45                       26.5
#
# essence                                                                              \
# races                                                                            25
# method2          nsample_10.0  nsample_4.0  smac  uniform  ksample_first-100.0-10.0
# total_timeout_h
# 3.00                      NaN          NaN   NaN      NaN                       NaN
# 5.25                      NaN          NaN   NaN      NaN                       NaN
# 6.00                     45.0           23  45.0     45.0                        45
# 12.00                    26.5           45  45.0      1.0                         6
# 21.00                     NaN          NaN   NaN      NaN                       NaN
# 24.00                    23.0           45  25.5     24.5                        23
#
# essence                                                                                          \
# races
# method2          ksample_first-20.0-10.0  ksample_halving-100.0-10.0  ksample_halving-20.0-10.0
# total_timeout_h
# 3.00                                 NaN                         NaN                        NaN
# 5.25                                 NaN                         NaN                        NaN
# 6.00                                  23                        30.0                       23.0
# 12.00                                  1                        26.5                       23.0
# 21.00                                NaN                         NaN                        NaN
# 24.00                                 45                        45.0                       24.5
#
# essence                                                                              \
# races                                                                            50
# method2          nsample_10.0  nsample_4.0  smac  uniform  ksample_first-100.0-10.0
# total_timeout_h
# 3.00                      NaN          NaN   NaN      NaN                       NaN
# 5.25                      NaN          NaN   NaN      NaN                       NaN
# 6.00                     45.0            3    23     23.5                      45.0
# 12.00                    45.0           45    45      9.5                       1.0
# 21.00                     NaN          NaN   NaN      NaN                       NaN
# 24.00                    27.5           45    23     45.0                       4.5
#
# essence                                                                                          \
# races
# method2          ksample_first-20.0-10.0  ksample_halving-100.0-10.0  ksample_halving-20.0-10.0
# total_timeout_h
# 3.00                                 NaN                         NaN                        NaN
# 5.25                                 NaN                         NaN                        NaN
# 6.00                                  45                        45.0                       45.0
# 12.00                                 45                        45.0                       26.0
# 21.00                                NaN                         NaN                        NaN
# 24.00                                 30                        26.5                        4.5
#
# essence                                                         prob010-SCP                   \
# races                                                                    5
# method2          nsample_10.0  nsample_4.0  smac  uniform  markov_10.0_10.0  markov_10.0_4.0
# total_timeout_h
# 3.00                      NaN          NaN   NaN      NaN               4.0              4.0
# 5.25                      NaN          NaN   NaN      NaN               NaN              NaN
# 6.00                     45.0         30.0  23.0     45.0               4.0              2.5
# 12.00                    32.0          1.0  26.5      3.5               NaN              NaN
# 21.00                     NaN          NaN   NaN      NaN               2.5              4.0
# 24.00                    26.5         26.5  10.5     45.0               NaN              NaN
#
# essence                                                                                           \
# races
# method2          markov_1000.0_10.0  markov_1000.0_4.0  nsample_10.0  nsample_4.0  smac  uniform
# total_timeout_h
# 3.00                            4.0                4.0             4            4     4        4
# 5.25                            NaN                NaN           NaN          NaN   NaN      NaN
# 6.00                            4.0                2.5             3            4     3        4
# 12.00                           NaN                NaN           NaN          NaN   NaN      NaN
# 21.00                           2.5                2.5             4            1     4        4
# 24.00                           NaN                NaN           NaN          NaN   NaN      NaN
#
# essence                                                                                           \
# races                                   10
# method2          ksample_first-1000.0-10.0  ksample_first-20.0-10.0  ksample_halving-1000.0-10.0
# total_timeout_h
# 3.00                                     4                        4                            4
# 5.25                                   NaN                      NaN                          NaN
# 6.00                                     4                        3                            4
# 12.00                                  NaN                      NaN                          NaN
# 21.00                                    4                        4                            4
# 24.00                                  NaN                      NaN                          NaN
#
# essence                                                                                            \
# races
# method2          ksample_halving-20.0-10.0  markov_10.0_10.0  markov_10.0_4.0  markov_1000.0_10.0
# total_timeout_h
# 3.00                                     4               2.5              2.5                   4
# 5.25                                   NaN               NaN              NaN                 NaN
# 6.00                                     4               2.5              4.0                   4
# 12.00                                  NaN               NaN              NaN                 NaN
# 21.00                                    4               2.5              4.0                   4
# 24.00                                  NaN               NaN              NaN                 NaN
#
# essence                                                                                                  \
# races                                                                                                25
# method2          markov_1000.0_4.0  nsample_10.0  nsample_4.0  smac  uniform  ksample_first-1000.0-10.0
# total_timeout_h
# 3.00                           4.0           4.0          4.0     4      4.0                        2.5
# 5.25                           NaN           NaN          NaN   NaN      NaN                        NaN
# 6.00                           3.5           4.0          4.0     4      2.5                        4.0
# 12.00                          NaN           NaN          NaN   NaN      NaN                        NaN
# 21.00                          2.5           2.5          2.5     4      4.0                        2.5
# 24.00                          NaN           NaN          NaN   NaN      NaN                        NaN
#
# essence                                                                                           \
# races
# method2          ksample_first-20.0-10.0  ksample_halving-1000.0-10.0  ksample_halving-20.0-10.0
# total_timeout_h
# 3.00                                 4.0                            4                        4.0
# 5.25                                 NaN                          NaN                        NaN
# 6.00                                 1.0                            4                        2.5
# 12.00                                NaN                          NaN                        NaN
# 21.00                                1.5                            4                        1.5
# 24.00                                NaN                          NaN                        NaN
#
# essence                                                                                                  \
# races
# method2          markov_10.0_10.0  markov_10.0_4.0  markov_1000.0_10.0  markov_1000.0_4.0  nsample_10.0
# total_timeout_h
# 3.00                          4.0                4                 4.0                  4           3.0
# 5.25                          NaN              NaN                 NaN                NaN           NaN
# 6.00                          4.0                4                 2.5                  3           2.5
# 12.00                         NaN              NaN                 NaN                NaN           NaN
# 21.00                         2.5                4                 2.5                  3           2.5
# 24.00                         NaN              NaN                 NaN                NaN           NaN
#
# essence                                                                                          \
# races                                                               50
# method2          nsample_4.0  smac  uniform  ksample_first-1000.0-10.0  ksample_first-20.0-10.0
# total_timeout_h
# 3.00                     4.0     4      2.0                        1.5                      4.0
# 5.25                     NaN   NaN      NaN                        NaN                      NaN
# 6.00                     2.5     4      4.0                        3.0                      2.5
# 12.00                    NaN   NaN      NaN                        NaN                      NaN
# 21.00                    4.0     2      2.5                        1.5                      3.0
# 24.00                    NaN   NaN      NaN                        NaN                      NaN
#
# essence                                                                          prob024-Langford  \
# races                                                                                          5
# method2          ksample_halving-1000.0-10.0  ksample_halving-20.0-10.0  ksample_first-100.0-10.0
# total_timeout_h
# 3.00                                       3                        2.5                       NaN
# 5.25                                     NaN                        NaN                       4.5
# 6.00                                       3                        4.0                       NaN
# 12.00                                    NaN                        NaN                      79.0
# 21.00                                      2                        1.0                       NaN
# 24.00                                    NaN                        NaN                       4.0
#
# essence                                                                                          \
# races
# method2          ksample_first-20.0-10.0  ksample_halving-100.0-10.0  ksample_halving-20.0-10.0
# total_timeout_h
# 3.00                                 NaN                         NaN                        NaN
# 5.25                                79.0                         3.5                          4
# 6.00                                 NaN                         NaN                        NaN
# 12.00                               79.5                       154.0                          3
# 21.00                                NaN                         NaN                        NaN
# 24.00                               81.0                         3.0                         79
#
# essence                                                                                                 \
# races                                                                      10
# method2          nsample_10.0  nsample_4.0  uniform  ksample_first-100.0-10.0  ksample_first-20.0-10.0
# total_timeout_h
# 3.00                      NaN          NaN      NaN                       NaN                      NaN
# 5.25                      NaN          NaN       79                      80.5                     78.0
# 6.00                      4.5          3.5      NaN                       NaN                      NaN
# 12.00                   154.0          4.0       80                       3.0                      2.0
# 21.00                     NaN          NaN      NaN                       NaN                      NaN
# 24.00                     4.0        154.0       34                      80.0                      2.5
#
# essence                                                                                                     \
# races
# method2          ksample_halving-100.0-10.0  ksample_halving-20.0-10.0  nsample_10.0  nsample_4.0  uniform
# total_timeout_h
# 3.00                                    NaN                        NaN           NaN          NaN      NaN
# 5.25                                    4.5                       80.0           NaN          NaN     80.5
# 6.00                                    NaN                        NaN           9.5          6.0      NaN
# 12.00                                   3.0                        3.5          78.5         81.0     81.0
# 21.00                                   NaN                        NaN           NaN          NaN      NaN
# 24.00                                   3.0                        3.0           5.5         78.5     78.0
#
# essence                                                                                         \
# races                                  25
# method2          ksample_first-100.0-10.0  ksample_first-20.0-10.0  ksample_halving-100.0-10.0
# total_timeout_h
# 3.00                                  NaN                      NaN                         NaN
# 5.25                                154.0                    154.0                       154.0
# 6.00                                  NaN                      NaN                         NaN
# 12.00                                 3.5                      5.5                         6.5
# 21.00                                 NaN                      NaN                         NaN
# 24.00                                 4.0                      2.5                         3.5
#
# essence                                                                                                   \
# races                                                                                                 50
# method2          ksample_halving-20.0-10.0  nsample_10.0  nsample_4.0  uniform  ksample_first-100.0-10.0
# total_timeout_h
# 3.00                                   NaN           NaN          NaN      NaN                       NaN
# 5.25                                 154.0           NaN          NaN    154.0                       NaN
# 6.00                                   NaN         154.0          154      NaN                       NaN
# 12.00                                  4.5           3.5           79     15.5                       154
# 21.00                                  NaN           NaN          NaN      NaN                       NaN
# 24.00                                  3.0           4.5            4     79.0                         3
#
# essence                                                                                          \
# races
# method2          ksample_first-20.0-10.0  ksample_halving-100.0-10.0  ksample_halving-20.0-10.0
# total_timeout_h
# 3.00                                 NaN                         NaN                        NaN
# 5.25                                 NaN                         NaN                        NaN
# 6.00                                 NaN                         NaN                        NaN
# 12.00                              154.0                       154.0                      154.0
# 21.00                                NaN                         NaN                        NaN
# 24.00                                4.5                         3.5                        4.5
#
# essence                                                          prob028-Bibd                           \
# races                                                                      5
# method2          nsample_10.0  nsample_4.0  uniform  ksample_first-100.0-10.0  ksample_first-20.0-10.0
# total_timeout_h
# 3.00                      NaN          NaN      NaN                       NaN                      NaN
# 5.25                      NaN          NaN      NaN                       NaN                      NaN
# 6.00                    154.0        154.0      NaN                         1                        1
# 12.00                   154.0        154.0    154.0                         1                        1
# 21.00                     NaN          NaN      NaN                       NaN                      NaN
# 24.00                     4.5          5.5      5.5                       NaN                        1
#
# essence                                                                                                    \
# races                                                                                                  10
# method2          ksample_halving-100.0-10.0  ksample_halving-20.0-10.0  uniform  ksample_first-100.0-10.0
# total_timeout_h
# 3.00                                    NaN                        NaN      NaN                       NaN
# 5.25                                    NaN                        NaN      NaN                       NaN
# 6.00                                      1                          1        1                         1
# 12.00                                     1                          1        1                         1
# 21.00                                   NaN                        NaN      NaN                       NaN
# 24.00                                   NaN                        NaN        1                       NaN
#
# essence                                                                                                   \
# races
# method2          ksample_first-20.0-10.0  ksample_halving-100.0-10.0  ksample_halving-20.0-10.0  uniform
# total_timeout_h
# 3.00                                 NaN                         NaN                        NaN      NaN
# 5.25                                 NaN                         NaN                        NaN      NaN
# 6.00                                   1                           1                          1        1
# 12.00                                  1                           1                          1        1
# 21.00                                NaN                         NaN                        NaN      NaN
# 24.00                                NaN                         NaN                        NaN        1
#
# essence                                                                                         \
# races                                  25
# method2          ksample_first-100.0-10.0  ksample_first-20.0-10.0  ksample_halving-100.0-10.0
# total_timeout_h
# 3.00                                  NaN                      NaN                         NaN
# 5.25                                  NaN                      NaN                         NaN
# 6.00                                  141                       71                          71
# 12.00                                   1                        1                           1
# 21.00                                 NaN                      NaN                         NaN
# 24.00                                 NaN                      NaN                         NaN
#
# essence                                                                                                 \
# races                                                                      50
# method2          ksample_halving-20.0-10.0  uniform  ksample_first-100.0-10.0  ksample_first-20.0-10.0
# total_timeout_h
# 3.00                                   NaN      NaN                       NaN                      NaN
# 5.25                                   NaN      NaN                       NaN                      NaN
# 6.00                                   141      141                       141                      141
# 12.00                                    1        1                         1                        1
# 21.00                                  NaN      NaN                       NaN                      NaN
# 24.00                                  NaN        1                       NaN                      NaN
#
# essence
# races
# method2          ksample_halving-100.0-10.0  ksample_halving-20.0-10.0  uniform
# total_timeout_h
# 3.00                                    NaN                        NaN      NaN
# 5.25                                    NaN                        NaN      NaN
# 6.00                                    141                        141      141
# 12.00                                     1                          1        1
# 21.00                                   NaN                        NaN      NaN
# 24.00                                   NaN                        NaN        1

# %%
a=c[ c.essence =='efpa'  ].pivot_table(rows=['total_timeout_h'],
                       cols=['essence','races','method2'],
                       values='resulting_models_filled')

b=c[ c.essence =='efpa'  ].pivot_table(rows=['total_timeout_h'],
                       cols=['essence', 'races', 'method2', 'run_no'],
                       values='resulting_models_filled')

# display(a,b)

totals = { k :0 for k in c.method2.unique() }

num =5
text='Number of configuration that are left with less then {}% of the models'.format(num)
for e_name in c.essence.unique():
    d=c[(c.essence==e_name)]
    d['method2_count'] = d['method2']
    d.method2_count=d.method2_count.apply(func=lambda x:len(d[d.method2 ==x]) )
    d[text]=1
    d['bound'] = d.num_models * num / 100.0 
    d['bound'] = d['bound'].apply(func=lambda x: 1.01 if x < 1.01 else x )
    
    per_10= d[ d.resulting_models_filled <= d.bound    ].drop(["output_dir"],axis=1).sort(axis=0, columns='method2')
    pt=per_10.pivot_table(rows=['total_timeout_h'],
                       cols=['essence', 'races', 'method2', 'run_no'],
                       values='resulting_models_filled')

    print(d.bound.unique())
    pt2=per_10.pivot_table(rows=['total_timeout_h'], cols=['essence','method2'], values=[text], dropna=False, 
                   aggfunc=lambda x: len(x), margins=True )

    display(pt2)
#     add the counts to totals
    counts = { c[-1]:v for (c, v) in zip(pt2.columns, pt2[-1:len(pt2)].values[0][0:-1] )}
    for (k,v) in counts.items():
        totals[k] +=v

display("Totals for " + text, sorted(totals.items(), key=lambda x: x[1], reverse=True ) )
# Out:
# [ 7.05]
#                  Number of configuration that are left with less then 5% of the models  \
# essence                                                                   prob028-Bibd
# method2                                                       ksample_first-100.0-10.0
# total_timeout_h
# 6.0                                                              4
# 12.0                                                             8
# 24.0                                                           NaN
# All                                                             12
#
#                                                                                                           \
# essence
# method2          ksample_first-20.0-10.0  ksample_halving-100.0-10.0  ksample_halving-20.0-10.0  uniform
# total_timeout_h
# 6.0                                    5                           5                          4        4
# 12.0                                   8                           8                          8        8
# 24.0                                   1                         NaN                        NaN        8
# All                                   14                          13                         12       20
#
#
# essence          All
# method2
# total_timeout_h
# 6.0               22
# 12.0              40
# 24.0               9
# All               71
# [ 2.25]
#                  Number of configuration that are left with less then 5% of the models  \
# essence                                                                           efpa
# method2                                                       ksample_first-100.0-10.0
# total_timeout_h
# 6.0                                                              1
# 12.0                                                             3
# 24.0                                                             2
# All                                                              6
#
#                                                                                                       \
# essence
# method2          ksample_first-20.0-10.0  ksample_halving-20.0-10.0  nsample_10.0  nsample_4.0  smac
# total_timeout_h
# 6.0                                    1                          1           NaN            2     2
# 12.0                                   3                          1           NaN            2   NaN
# 24.0                                 NaN                          1             1            1     2
# All                                    4                          3             1            5     4
#
#
# essence                   All
# method2          uniform
# total_timeout_h
# 6.0                    1    8
# 12.0                   2   11
# 24.0                 NaN    7
# All                    3   26
# [ 7.7]
#                  Number of configuration that are left with less then 5% of the models  \
# essence                                                               prob024-Langford
# method2                                                       ksample_first-100.0-10.0
# total_timeout_h
# 5.25                                                             3
# 6.0                                                            NaN
# 12.0                                                             5
# 24.0                                                             7
# All                                                             15
#
#                                                                                                  \
# essence
# method2          ksample_first-20.0-10.0  ksample_halving-100.0-10.0  ksample_halving-20.0-10.0
# total_timeout_h
# 5.25                                   2                           4                          3
# 6.0                                  NaN                         NaN                        NaN
# 12.0                                   5                           4                          6
# 24.0                                   6                           8                          7
# All                                   13                          16                         16
#
#
# essence                                              All
# method2          nsample_10.0  nsample_4.0  uniform
# total_timeout_h
# 5.25                      NaN          NaN        2   14
# 6.0                         3            4      NaN    7
# 12.0                        3            3        2   28
# 24.0                        8            5        5   46
# All                        14           12        9   95
# [ 1.01]
#                  Number of configuration that are left with less then 5% of the models  \
# essence                                                                    prob010-SCP
# method2                                                      ksample_first-1000.0-10.0
# total_timeout_h
# 3.0                                                              2
# 6.0                                                            NaN
# 21.0                                                             2
# All                                                              4
#
#                                                                                                         \
# essence
# method2          ksample_first-20.0-10.0  ksample_halving-20.0-10.0  markov_10.0_10.0  markov_10.0_4.0
# total_timeout_h
# 3.0                                  NaN                          1                 1                1
# 6.0                                    3                          1                 1                1
# 21.0                                   1                          3                 3              NaN
# All                                    4                          5                 5                2
#
#
# essence                                                                                     All
# method2          markov_1000.0_10.0  markov_1000.0_4.0  nsample_10.0  nsample_4.0  uniform
# total_timeout_h
# 3.0                             NaN                NaN           NaN          NaN      NaN    5
# 6.0                               1                  1             1            1        1   11
# 21.0                              2                  2             2            3        1   19
# All                               3                  3             3            4        2   35
# 'Totals for Number of configuration that are left with less then 5% of the models'
# [('ksample_halving-20.0-10.0', 36.0),
#  ('ksample_first-20.0-10.0', 35.0),
#  ('uniform', 34.0),
#  ('ksample_first-100.0-10.0', 33.0),
#  ('ksample_halving-100.0-10.0', 29.0),
#  ('nsample_4.0', 21.0),
#  ('nsample_10.0', 18.0),
#  ('markov_10.0_10.0', 5.0),
#  ('ksample_first-1000.0-10.0', 4.0),
#  ('smac', 4.0),
#  ('markov_1000.0_4.0', 3.0),
#  ('markov_1000.0_10.0', 3.0),
#  ('markov_10.0_4.0', 2.0),
#  ('ksample_halving-1000.0-10.0', 0)]

# %%
for e_name in c.essence.unique():
    d=c[(c.essence==e_name)]
    d['method2_count'] = d['method2']
    d.method2_count=d.method2_count.apply(func=lambda x:len(d[d.method2 ==x]) )
    
    y=d[ ['method2', 'method2_count' ] ]
    display(e_name, y.drop_duplicates().sort(columns=['method2','method2_count']))

    
c['method2_count'] = c['method2']
c.method2_count=c.method2_count.apply(func=lambda x:len( c[c.method2 ==x]) )
x=c[ ['method2', 'method2_count' ] ]
display("total", x.drop_duplicates().sort(columns=['method2','method2_count']))
# Out:
# 'prob028-Bibd'
#                         method2  method2_count
# 4      ksample_first-100.0-10.0             16
# 0       ksample_first-20.0-10.0             17
# 6    ksample_halving-100.0-10.0             16
# 2     ksample_halving-20.0-10.0             16
# 292                     uniform             24
# 'efpa'
#                         method2  method2_count
# 57     ksample_first-100.0-10.0             24
# 53      ksample_first-20.0-10.0             24
# 59   ksample_halving-100.0-10.0             24
# 55    ksample_halving-20.0-10.0             24
# 11             markov_10.0_10.0              4
# 9               markov_10.0_4.0              4
# 15           markov_1000.0_10.0              3
# 13            markov_1000.0_4.0              4
# 26                 nsample_10.0             24
# 24                  nsample_4.0             24
# 120                        smac             24
# 144                     uniform             24
# 'prob024-Langford'
#                         method2  method2_count
# 207    ksample_first-100.0-10.0             22
# 203     ksample_first-20.0-10.0             22
# 209  ksample_halving-100.0-10.0             22
# 205   ksample_halving-20.0-10.0             22
# 107                nsample_10.0             24
# 108                 nsample_4.0             24
# 276                     uniform             22
# 'prob010-SCP'
#                          method2  method2_count
# 554    ksample_first-1000.0-10.0             18
# 550      ksample_first-20.0-10.0             18
# 556  ksample_halving-1000.0-10.0             18
# 552    ksample_halving-20.0-10.0             18
# 424             markov_10.0_10.0             18
# 430              markov_10.0_4.0             18
# 428           markov_1000.0_10.0             18
# 426            markov_1000.0_4.0             18
# 456                 nsample_10.0             18
# 454                  nsample_4.0             18
# 532                         smac             18
# 634                      uniform             18
# 'total'
#                          method2  method2_count
# 4       ksample_first-100.0-10.0             62
# 554    ksample_first-1000.0-10.0             18
# 0        ksample_first-20.0-10.0             81
# 6     ksample_halving-100.0-10.0             62
# 556  ksample_halving-1000.0-10.0             18
# 2      ksample_halving-20.0-10.0             80
# 11              markov_10.0_10.0             22
# 9                markov_10.0_4.0             22
# 15            markov_1000.0_10.0             21
# 13             markov_1000.0_4.0             22
# 26                  nsample_10.0             66
# 24                   nsample_4.0             66
# 120                         smac             42
# 144                      uniform             88

# %%
x
