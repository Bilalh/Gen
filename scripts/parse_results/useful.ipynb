# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

from analyse import *

df = load_data_frame()
pd.options.display.line_width = 110
pd.options.display.max_columns = 50
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 0 to 599
# Data columns (total 18 columns):
# chain_length               72  non-null values
# discriminating             600  non-null values
# essence                    600  non-null values
# influence_radius           476  non-null values
# method                     600  non-null values
# models_timeout             600  non-null values
# num_models                 600  non-null values
# num_points                 320  non-null values
# output_dir                 600  non-null values
# point_selector             320  non-null values
# quality                    243  non-null values
# races                      600  non-null values
# radius_as_percentage       476  non-null values
# run_no                     600  non-null values
# total_timeout              600  non-null values
# resulting_models           243  non-null values
# resulting_models_filled    600  non-null values
# total_timeout_h            600  non-null values
# dtypes: float64(8), int64(6), object(4)

# %%
our = df[ (df['total_timeout_h'] >=1 ) ]

pt=our.pivot_table(rows=['total_timeout_h'],
                   cols=['essence','races','method' ],
                   values='resulting_models_filled')

cols = our['races'].unique()
rows = our['essence'].unique()

lens = ( (i,j, pt[r][c].columns ) for i, r in  enumerate(rows)  for j, c in enumerate(cols) )
max_val = max(lens,key=lambda v: len(v[2]))
*max_val, legend_names = max_val

styles = ['bo-','ro-','go-', 'yo-', 'mo-', 'ko-']
styles_mapping = make_style_mapping(legend_names, styles)


fig, axes = plt.subplots(nrows=len(rows), ncols=len(cols), figsize=(22, 17), sharex=True, sharey='row')
for i, v1 in enumerate( rows ):
    for j, v2 in enumerate( cols ):
        col_names = tuple(pt[v1][v2].columns)
        pt[v1][v2].dropna().plot(ax=axes[i][j],
                                 title="{} races, {}".format(v2, v1), 
                                 style=list(styles_mapping[col_names]), 
                                 legend=False)
    axes[i][0].set_ylabel('models left')
    

fig.legend( axes[max_val[0]][max_val[1]].get_lines() ,
           legend_names, 
           loc = 'upper center', 
           ncol=5 )

from matplotlib.backends.backend_pdf import PdfPages
with PdfPages('/Users/bilalh/Desktop/a.pdf') as pdf:
    pdf.savefig()
    
# fig.savefig('/Users/bilalh/Desktop/a.png')

# %%
our = df[ (df['total_timeout_h'] >=3 ) ]
pt=our.pivot_table(rows=['total_timeout_h'],
                   cols=['essence','races','method' ],
                   values='resulting_models_filled')
pt
# Out:
# essence             efpa                                      prob010-SCP                                   \
# races                 5                 10       25       50           5                                10
# method           ksample  uniform  uniform  uniform  uniform       markov  nsample  smac  uniform  ksample
# total_timeout_h
# 3.00                 NaN      NaN      NaN      NaN      NaN        4.000      4.0     4        4     4.00
# 5.25                 NaN      NaN      NaN      NaN      NaN          NaN      NaN   NaN      NaN      NaN
# 6.00              39.875       45     45.0     23.5     45.0        3.250      3.5     3        4     3.75
# 12.00             39.875       45      1.0      9.5      3.5          NaN      NaN   NaN      NaN      NaN
# 21.00                NaN      NaN      NaN      NaN      NaN        2.875      2.5     4        4     4.00
# 24.00             45.000       45     24.5     45.0     45.0          NaN      NaN   NaN      NaN      NaN
#
# essence                                                                                            \
# races                                                 25                                       50
# method           markov  nsample  smac  uniform  ksample  markov  nsample  smac  uniform  ksample
# total_timeout_h
# 3.00               3.25      4.0     4      4.0    3.625   4.000     3.50     4      2.0    2.750
# 5.25                NaN      NaN   NaN      NaN      NaN     NaN      NaN   NaN      NaN      NaN
# 6.00               3.50      4.0     4      2.5    2.875   3.375     2.50     4      4.0    3.125
# 12.00               NaN      NaN   NaN      NaN      NaN     NaN      NaN   NaN      NaN      NaN
# 21.00              3.25      2.5     4      4.0    2.375   3.000     3.25     2      2.5    1.875
# 24.00               NaN      NaN   NaN      NaN      NaN     NaN      NaN   NaN      NaN      NaN
#
# essence          prob024-Langford                                                                          \
# races                          5                          10                         25
# method                    ksample  nsample  uniform  ksample  nsample  uniform  ksample  nsample  uniform
# total_timeout_h
# 3.00                          NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5.25                       22.750      NaN       79   60.750      NaN     80.5   154.00      NaN    154.0
# 6.00                          NaN        4      NaN      NaN     7.75      NaN      NaN   154.00      NaN
# 12.00                      78.875       79       80    2.875    79.75     81.0     5.00    41.25     15.5
# 21.00                         NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 24.00                      41.750       79       34   22.125    42.00     78.0     3.25     4.25     79.0
#
# essence                                     prob028-Bibd                                               \
# races                 50                              5                 10                25
# method           ksample  nsample  uniform       ksample  uniform  ksample  uniform  ksample  uniform
# total_timeout_h
# 3.00                 NaN      NaN      NaN           NaN      NaN      NaN      NaN      NaN      NaN
# 5.25                 NaN      NaN      NaN           NaN      NaN      NaN      NaN      NaN      NaN
# 6.00                 NaN      154      NaN             1        1        1        1      106      141
# 12.00            154.000      154    154.0             1        1        1        1        1        1
# 21.00                NaN      NaN      NaN           NaN      NaN      NaN      NaN      NaN      NaN
# 24.00              3.875        5      5.5             1        1      NaN        1      NaN        1
#
# essence
# races                 50
# method           ksample  uniform
# total_timeout_h
# 3.00                 NaN      NaN
# 5.25                 NaN      NaN
# 6.00                 141      141
# 12.00                  1        1
# 21.00                NaN      NaN
# 24.00                NaN        1

# %%
our = df[ (df['total_timeout_h'] >=1 ) & (df['method'] == 'ksample' )  ]

cols_names=['essence','races','run_no']

pt=our.pivot_table(rows=['total_timeout_h'],
                   cols=cols_names,
                   values='resulting_models_filled')

rows = our[cols_names[0]].unique()
cols = our[cols_names[1]].unique()

r_limits =( df['total_timeout_h'].dropna().min(),  df['total_timeout_h'].dropna().max())

lens = ( (i,j, pt[r][c].columns ) for i, r in  enumerate(rows)  for j, c in enumerate(cols) )
max_val = max(lens,key=lambda v: len(v[2]))
*max_val, legend_names = max_val

styles = ['bo-','ro-','go-', 'yo-', 'mo-', 'ko-']
styles_mapping = make_style_mapping(legend_names, styles)

fig, axes = plt.subplots(nrows=len(rows), ncols=len(cols), figsize=(22, 17), sharex=True, sharey='row')
for i, v1 in enumerate( rows ):
    col_vals= our[ (our[cols_names[0]] == v1) ]['total_timeout_h'].dropna()
    ylim = (col_vals.min(), col_vals.max())
    
    for j, v2 in enumerate( cols ):
        if pt[v1][v2].empty: # not done yet
            continue

        col_names = tuple(pt[v1][v2].columns)
        pt[v1][v2].dropna().plot(ax=axes[i][j],
                                 title="{}:{}, {}".format(cols_names[1], v2, v1), 
                                 style=list(styles_mapping[col_names]), 
                                 legend=True,
                                 xlim=r_limits,
                                 ylim=ylim)

    axes[i][0].set_ylabel('models left')
    

fig.legend( axes[max_val[0]][max_val[1]].get_lines() ,
           legend_names, 
           loc = 'upper center', 
           ncol=5 )

from matplotlib.backends.backend_pdf import PdfPages
with PdfPages('/Users/bilalh/Desktop/b.pdf') as pdf:
    pdf.savefig()
    
# fig.savefig('/Users/bilalh/Desktop/a.png')

# %%
our = df[ (df['total_timeout_h'] >=1 ) & (df['method'] == 'ksample' )  ]

cols_names=['essence','races','run_no']

pt=our.pivot_table(rows=['total_timeout_h'],
                   cols=cols_names,
                   values='resulting_models_filled')

rows = our[cols_names[0]].unique()
cols = our[cols_names[1]].unique()

r_limits =( df['total_timeout_h'].dropna().min(),  df['total_timeout_h'].dropna().max())
c_limits =( 0,  df['num_models'][0] )


print(rows, cols, r_limits, c_limits)
pt
# Out:
# ['efpa' 'prob024-Langford' 'prob028-Bibd' 'prob010-SCP'] [ 5 50 25 10] (0.375, 24.0) (0, 154)
# essence          efpa         prob010-SCP                              prob024-Langford                  \
# races              5                   10        25          50                      5               10
# run_no              1      2            1   2     1     2     1     2                 1       2       1
# total_timeout_h
# 2.625             NaN    NaN          NaN NaN   NaN   NaN   NaN   NaN             56.50  117.50  154.00
# 3.000             NaN    NaN          4.0   4  4.00  3.25  2.25  3.25               NaN     NaN     NaN
# 5.250             NaN    NaN          NaN NaN   NaN   NaN   NaN   NaN              4.00   41.50   80.00
# 6.000              45  34.75          3.5   4  3.25  2.50  4.00  2.25               NaN     NaN     NaN
# 12.000             45  34.75          NaN NaN   NaN   NaN   NaN   NaN             78.75   79.00    2.50
# 21.000            NaN    NaN          4.0   4  2.00  2.75  1.50  2.25               NaN     NaN     NaN
# 24.000             45  45.00          NaN NaN   NaN   NaN   NaN   NaN             78.75    4.75   40.25
#
# essence                                           prob028-Bibd
# races                     25             50                 5       10       25        50
# run_no                2    1      2       1    2             1   2   1   2    1    2    1    2
# total_timeout_h
# 2.625            154.00  154  154.0     NaN  NaN           NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 3.000               NaN  NaN    NaN     NaN  NaN           NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 5.250             41.50  154  154.0     NaN  NaN           NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 6.000               NaN  NaN    NaN     NaN  NaN             1   1   1   1  106  106  141  141
# 12.000             3.25    5    5.0  154.00  154             1   1   1   1    1    1    1    1
# 21.000              NaN  NaN    NaN     NaN  NaN           NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 24.000             4.00    3    3.5    3.75    4             1 NaN NaN NaN  NaN  NaN  NaN  NaN
